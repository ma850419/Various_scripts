# %% [markdown]
# <a href="https://colab.research.google.com/github/ma850419/Various_scripts/blob/main/statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the data
df = pd.read_csv("C:/Users/Dr. Mohamad Awad/Downloads/adult/adult.csv", na_values='?')

# Dataset Overview
df.head() # preview a sample

df.shape  # number of observations and features
# (32561, 15)

df.dtypes # data types
#age                int64
#workclass         object
#fnlwgt             int64
#education         object
# (...)

df[df.duplicated()] # check duplicated rows

print(df.isna().sum()) # missing values per feature
#age                  0
#workclass         1836
#fnlwgt               0
# (...)

df.isna().sum().sum() # number of missing cells
round(df.isna().sum().sum() / df.size * 100, 1) # percentage of missing cells
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64
# 0.9

# %%
cat_cols = ['workclass', 'education', 'education.num',
            'marital.status', 'occupation', 'relationship', 'race',
            'sex', 'native.country', 'income']

for col in cat_cols:
    categories = df.groupby(col).size()
    print(categories)

#workclass
#Federal-gov           960
#Local-gov            2093
#Never-worked            7
# (...)
#education
#10th              933
#11th             1175
#12th              433
# (...)
# Out:
# workclass
# Federal-gov           960
# Local-gov            2093
# Never-worked            7
# Private             22696
# Self-emp-inc         1116
# Self-emp-not-inc     2541
# State-gov            1298
# Without-pay            14
# dtype: int64
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           646
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5355
# Doctorate         413
# HS-grad         10501
# Masters          1723
# Preschool          51
# Prof-school       576
# Some-college     7291
# dtype: int64
# education.num
# 1        51
# 2       168
# 3       333
# 4       646
# 5       514
# 6       933
# 7      1175
# 8       433
# 9     10501
# 10     7291
# 11     1382
# 12     1067
# 13     5355
# 14     1723
# 15      576
# 16      413
# dtype: int64
# marital.status
# Divorced                  4443
# Married-AF-spouse           23
# ...

# %%
# Make the necessary imports
import pandas as pd
from ydata_profiling import ProfileReport

# Load the data
df = pd.read_csv("C:/Users/Dr. Mohamad Awad/Downloads/adult/adult.csv", na_values='?')

# Generate the report
profile = ProfileReport(df,title="Adult Census Profile")

# Save the report to .html
profile.to_file("adult_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached typeguard-4.4.1-py3-none-any.whl.metadata (3.7 kB)
# ...
#    ---------------------------------------- 0.0/390.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/390.9 kB ? eta -:--:--
#    --- ------------------------------------ 30.7/390.9 kB 1.4 MB/s eta 0:00:01
#    --- ------------------------------------ 30.7/390.9 kB 1.4 MB/s eta 0:00:01
#    ------ -------------------------------- 61.4/390.9 kB 365.7 kB/s eta 0:00:01
#    --------- ----------------------------- 92.2/390.9 kB 479.1 kB/s eta 0:00:01
#    --------- ----------------------------- 92.2/390.9 kB 479.1 kB/s eta 0:00:01
#    --------- ----------------------------- 92.2/390.9 kB 479.1 kB/s eta 0:00:01
#    ---------------- --------------------- 174.1/390.9 kB 499.5 kB/s eta 0:00:01
#    ------------------ ------------------- 194.6/390.9 kB 537.4 kB/s eta 0:00:01
# ...
